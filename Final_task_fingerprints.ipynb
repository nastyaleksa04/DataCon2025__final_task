# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = '/content/drive/MyDrive/HAKATON/Final task'

# %%
# Чтение данных
import pandas as pd
data = pd.read_csv(os.path.join(path, "HDAC6_clear.tsv"), sep='\t')
data
# Out:
#       BindingDB Reactant_set_id  \
# 0                      50237184
# 1                      51418458
# 2                      51418463
# 3                      50237182
# 4                      51418459
# ...                         ...
# 5360                    1057530
# 5361                    1057627
# 5362                    1057717
# 5363                    1056788
# 5364                    1056861
#
#                                           Ligand SMILES  \
# 0     Cc1cccc(NC(=O)[C@H](CCCCCS)NC(=O)[C@@H]2CCCC(=...
# 1                      ONC(=O)c1cc(F)c2CN(CCc2c1)C1CCC1
# 2           CN1CC2(CCCCC2)CC[C@H]1Cc1cc(F)cc(c1)C(=O)NO
# 3      SCCCCC[C@H](NC(=O)[C@@H]1CCCNC1=O)C(=O)Nc1ccccc1
# 4             Cn1c2CN(Cc3ccc(cc3F)C(=O)NO)CCc2c2ccccc12
# ...                                                 ...
# 5360  CC1(C)CCCCN1C(=O)[C@@H]1CCC(=O)N1c1ccc(-c2noc(...
# 5361          FC(F)(F)c1nc(no1)-c1ccc(CNC2CCCCNC2=O)nc1
# 5362         COc1cccc(NCc2ccc(cc2)-c2noc(n2)C(F)(F)F)c1
# 5363  CN1CCN(CC(=O)N(Cc2ccc(cc2)-c2noc(n2)C(F)(F)F)c...
# 5364  Cc1noc(n1)[C@H]1CCCCN1c1cc(F)c(cc1F)-c1noc(n1)...
#
#                                            Ligand InChI  \
# 0     InChI=1S/C20H29N3O3S/c1-14-7-5-8-15(13-14)21-1...
# 1     InChI=1S/C14H17FN2O2/c15-13-7-10(14(18)16-19)6...
# 2     InChI=1S/C19H27FN2O2/c1-22-13-19(6-3-2-4-7-19)...
# 3     InChI=1S/C19H27N3O3S/c23-17-15(10-7-12-20-17)1...
# 4     InChI=1S/C20H20FN3O2/c1-23-18-5-3-2-4-15(18)16...
# ...                                                 ...
# 5360  InChI=1S/C21H22F4N4O3/c1-20(2)9-3-4-10-28(20)1...
# 5361  InChI=1S/C15H16F3N5O2/c16-15(17,18)14-22-12(23...
# 5362  InChI=1S/C17H14F3N3O2/c1-24-14-4-2-3-13(9-14)2...
# 5363  InChI=1S/C24H23F6N5O2/c1-33-9-11-34(12-10-33)1...
# 5364  InChI=1S/C17H14F5N5O2/c1-8-23-15(28-25-8)12-4-...
#
#                  Ligand InChI Key  BindingDB MonomerID  \
# 0     JTIATMCBWUQBGH-IRXDYDNUSA-N             50027494
# 1     TWIFZMHPHFCCOU-UHFFFAOYSA-N             50573103
# 2     KDNQXZWMWWVUMN-KRWDZBQOSA-N             50573108
# 3     ILCBWDQDWOLKIQ-CVEARBPZSA-N             50027649
# 4     ZYAWIVYRYLKVIP-UHFFFAOYSA-N             50573104
# ...                           ...                  ...
# 5360  XLIIHBIXVZJLSA-HNNXBMFYSA-N               504941
# 5361  NFVVUJNRHLZQJQ-UHFFFAOYSA-N               504978
# 5362  FGRHBOCVOGOKKY-UHFFFAOYSA-N               505010
# 5363  WZCMOCJLIMWIOG-UHFFFAOYSA-N               504663
# 5364  KBURQWODNDVDIZ-GFCCVEGCSA-N               504695
#
#                                   BindingDB Ligand Name  \
# 0                                         CHEMBL3356916
# 1                                         CHEMBL4852905
# 2                                         CHEMBL4846606
# 3                                         CHEMBL3356527
# 4                                         CHEMBL4854340
# ...                                                 ...
# 5360  (5S)-5- [(2,2- dimethyl- piperidin- 1-yl) carb...
# 5361  3-[({5-[5- (trifluoro- methyl)- 1,2,4-oxa- dia...
# 5362  3-methoxy- N-{4-[5- (trifluoro- methyl)- 1,2,4...
# 5363  2-(4- methylpiperazin- 1-yl)-N-(4-(5- (trifluo...
# 5364  (R)-3-(2,5- difluoro-4-(2-(3- methyl-1,2,4- ox...
#
#                 Target Name  \
# 0     Histone deacetylase 6
# 1     Histone deacetylase 6
# 2     Histone deacetylase 6
# 3     Histone deacetylase 6
# 4     Histone deacetylase 6
# ...                     ...
# 5360  Histone deacetylase 6
# 5361  Histone deacetylase 6
# 5362  Histone deacetylase 6
# 5363  Histone deacetylase 6
# 5364  Histone deacetylase 6
#
#      Target Source Organism According to Curator or DataSource  Ki (nM)  \
# 0                                          Homo sapiens             NaN
# 1                                          Homo sapiens             NaN
# 2                                          Homo sapiens             NaN
# 3                                          Homo sapiens             NaN
# 4                                          Homo sapiens             NaN
# ...                                                 ...             ...
# 5360                                       Homo sapiens             NaN
# 5361                                       Homo sapiens             NaN
# 5362                                       Homo sapiens             NaN
# 5363                                       Homo sapiens             NaN
# 5364                                       Homo sapiens             NaN
#
#       IC50 (nM)  ...  UniProt (SwissProt) Entry Name of Target Chain  \
# 0           1.0  ...                                     HDAC6_HUMAN
# 1           1.0  ...                                     HDAC6_HUMAN
# 2           1.0  ...                                     HDAC6_HUMAN
# 3           1.0  ...                                     HDAC6_HUMAN
# 4           1.0  ...                                     HDAC6_HUMAN
# ...         ...  ...                                             ...
# 5360       64.0  ...                                     HDAC6_HUMAN
# 5361       64.0  ...                                     HDAC6_HUMAN
# 5362       64.0  ...                                     HDAC6_HUMAN
# 5363       64.0  ...                                     HDAC6_HUMAN
# 5364       64.0  ...                                     HDAC6_HUMAN
#
#       UniProt (SwissProt) Primary ID of Target Chain  \
# 0                                             Q9UBN7
# 1                                             Q9UBN7
# 2                                             Q9UBN7
# 3                                             Q9UBN7
# 4                                             Q9UBN7
# ...                                              ...
# 5360                                          Q9UBN7
# 5361                                          Q9UBN7
# 5362                                          Q9UBN7
# 5363                                          Q9UBN7
# 5364                                          Q9UBN7
#
#       UniProt (SwissProt) Secondary ID(s) of Target Chain  \
# 0                           O94975 Q6NT75 Q7L3E5 Q96CY0
# 1                           O94975 Q6NT75 Q7L3E5 Q96CY0
# 2                           O94975 Q6NT75 Q7L3E5 Q96CY0
# 3                           O94975 Q6NT75 Q7L3E5 Q96CY0
# 4                           O94975 Q6NT75 Q7L3E5 Q96CY0
# ...                                                 ...
# 5360                        O94975 Q6NT75 Q7L3E5 Q96CY0
# 5361                        O94975 Q6NT75 Q7L3E5 Q96CY0
# 5362                        O94975 Q6NT75 Q7L3E5 Q96CY0
# 5363                        O94975 Q6NT75 Q7L3E5 Q96CY0
# 5364                        O94975 Q6NT75 Q7L3E5 Q96CY0
#
#       UniProt (SwissProt) Alternative ID(s) of Target Chain  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5360                                                NaN
# 5361                                                NaN
# 5362                                                NaN
# 5363                                                NaN
# 5364                                                NaN
#
#       UniProt (TrEMBL) Submitted Name of Target Chain  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 5360                                              NaN
# 5361                                              NaN
# 5362                                              NaN
# 5363                                              NaN
# 5364                                              NaN
#
#      UniProt (TrEMBL) Entry Name of Target Chain  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 5360                                         NaN
# 5361                                         NaN
# 5362                                         NaN
# 5363                                         NaN
# 5364                                         NaN
#
#      UniProt (TrEMBL) Primary ID of Target Chain  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 5360                                         NaN
# 5361                                         NaN
# 5362                                         NaN
# 5363                                         NaN
# 5364                                         NaN
#
#      UniProt (TrEMBL) Secondary ID(s) of Target Chain  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 5360                                              NaN
# 5361                                              NaN
# 5362                                              NaN
# 5363                                              NaN
# 5364                                              NaN
#
#      UniProt (TrEMBL) Alternative ID(s) of Target Chain    pIC50
# 0                                                   NaN -0.00000
# 1                                                   NaN -0.00000
# 2                                                   NaN -0.00000
# 3                                                   NaN -0.00000
# 4                                                   NaN -0.00000
# ...                                                 ...      ...
# 5360                                                NaN -1.80618
# 5361                                                NaN -1.80618
# 5362                                                NaN -1.80618
# 5363                                                NaN -1.80618
# 5364                                                NaN -1.80618
#
# [5365 rows x 53 columns]

# %%
mol_column = "Ligand SMILES"
target_column = "pIC50"

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.11/dist-packages (2025.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
molecules = [Chem.MolFromSmiles(x) for x in data[mol_column]]

# %%
# from rdkit.Avalon import pyAvalonTools
# fingerprints = [pyAvalonTools.GetAvalonFP(mol, nBits=2048) for mol in molecules]

# %%
fpgen = AllChem.GetMorganGenerator(radius=2)
fingerprints = [list(fpgen.GetFingerprint(molecule)) for molecule in molecules]

# %%
# from rdkit.Chem import MACCSkeys
# fingerprints = [list(map(int,MACCSkeys.GenMACCSKeys(mol).ToBitString())) for mol in molecules]

# %%
target_prop = data[target_column]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(fingerprints, target_prop, test_size=0.2, random_state=42)

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import numpy as np

def get_regression_metrics(y_true, y_pred):
    metrics = {} # инициализируем словарь и рассчитываем основные регрессионные метрики
    metrics['R^2'] = round(r2_score(y_true, y_pred), 3) # коэффициент детерминации с точностью в 3 знака в дробной части
    metrics['MAE'] = round(mean_absolute_error(y_true, y_pred), 3) # MAE с точностью в 3 знака в дробной части
    metrics['RMSE'] = round(np.sqrt(mean_squared_error(y_true, y_pred)), 3) # RMSE с точностью в 3 знака пв дробной части
    return metrics # возвращаем словарь со всеми метриками


def reg_plot(y_true, y_pred, label='', units=''):
    plt.figure(figsize=(7, 7)) # задаем размер графика
    ax_min = np.min(np.hstack((y_true, y_pred))) - 0.5 # рассчитываем минимальное значение, отложенное на обеих осях
    ax_max = np.max(np.hstack((y_true, y_pred))) + 0.5 # рассчитываем максимальное значение, отложенное на обеих осях
    plt.xlim(ax_min, ax_max) # задаем диапазон значений для оси абсцисс
    plt.ylim(ax_min, ax_max) # задаем диапазон значений для оси ординат
    plt.scatter(y_true, y_pred, marker='*') # наносим на график точки с координатами (y_true_i, y_pred_i)
    plt.plot([ax_min, ax_max], [ax_min, ax_max], color='k', linestyle='-.') # штрихпунктирная линия x=y
    plt.xlabel(f'{label} calculated, [{units}]') # подпись к оси абсцисс
    plt.ylabel(f'{label} predicted, [{units}]') # подпись к оси ординат
    plt.gca().set_aspect('equal', adjustable='box') # задаём равный масштаб по оси абсцисс и ординат

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 500]
}

xgb = XGBRegressor(random_state=42)

grid_search = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)

best_rf = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits

# %%
print(get_regression_metrics(y_test, best_rf.predict(X_test)))
reg_plot(y_test, best_rf.predict(X_test), label='module')
# Out:
# {'R^2': 0.657, 'MAE': 0.423, 'RMSE': np.float64(0.582)}

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor(random_state=42)
xgb.fit(X_train, y_train)
print(get_regression_metrics(y_test, xgb.predict(X_test)))
reg_plot(y_test, xgb.predict(X_test), label='module')
# Out:
# {'R^2': 0.641, 'MAE': 0.435, 'RMSE': np.float64(0.596)}

# %%
from sklearn.neural_network import MLPRegressor
mlp = MLPRegressor(random_state=1234, max_iter=1000)
mlp.fit(X_train, y_train)
print(get_regression_metrics(y_test, mlp.predict(X_test)))
reg_plot(y_test, mlp.predict(X_test), label='module')
# Out:
# {'R^2': 0.57, 'MAE': 0.477, 'RMSE': np.float64(0.652)}

# %%
# Добавление дубликатов с наиболее близкими свойствами
dupl_data = pd.read_csv(os.path.join(path, "HDAC6_clear_all_dupl.tsv"), sep='\t')
dupl_data
# Out:
#                                           Ligand SMILES    pIC50
# 0               Nc1ccc(cc1)-c1nnn(Cc2ccc(cc2)C(=O)NO)n1 -0.00000
# 1               Nc1ccc(cc1)-c1nnn(Cc2ccc(cc2)C(=O)NO)n1 -0.00000
# 2      C[C@H](\C=C(/C)\C=C\C(=O)NO)C(=O)c1ccc(cc1)N(C)C -0.00000
# 3      C[C@H](\C=C(/C)\C=C\C(=O)NO)C(=O)c1ccc(cc1)N(C)C -0.00000
# 4              CC(C=CC(=O)NO)C=C(C)C(=O)c1ccc(cc1)N(C)C -0.00000
# ...                                                 ...      ...
# 8324  CC1(C)CCCCN1C(=O)[C@@H]1CCC(=O)N1c1ccc(-c2noc(... -1.80618
# 8325          FC(F)(F)c1nc(no1)-c1ccc(CNC2CCCCNC2=O)nc1 -1.80618
# 8326         COc1cccc(NCc2ccc(cc2)-c2noc(n2)C(F)(F)F)c1 -1.80618
# 8327  CN1CCN(CC(=O)N(Cc2ccc(cc2)-c2noc(n2)C(F)(F)F)c... -1.80618
# 8328  Cc1noc(n1)[C@H]1CCCCN1c1cc(F)c(cc1F)-c1noc(n1)... -1.80618
#
# [8329 rows x 2 columns]

# %%
dupl_data_molecules = [Chem.MolFromSmiles(mol) for mol in dupl_data["Ligand SMILES"]]
dupl_data_fingerprints = [list(fpgen.GetFingerprint(mol)) for mol in dupl_data_molecules]
dupl_data_prediction = best_rf.predict(dupl_data_fingerprints)
predictions = pd.DataFrame({"prediction": dupl_data_prediction})
predictions
# Out:
#       prediction
# 0      -1.219594
# 1      -1.219594
# 2      -2.531803
# 3      -2.531803
# 4      -1.088851
# ...          ...
# 8324   -1.834588
# 8325   -1.708438
# 8326   -1.769439
# 8327   -1.700194
# 8328   -1.901083
#
# [8329 rows x 1 columns]

# %%
dupl_data = pd.concat([dupl_data, predictions], axis=1)
dupl_data
# Out:
#                                           Ligand SMILES    pIC50  prediction
# 0               Nc1ccc(cc1)-c1nnn(Cc2ccc(cc2)C(=O)NO)n1 -0.00000   -1.219594
# 1               Nc1ccc(cc1)-c1nnn(Cc2ccc(cc2)C(=O)NO)n1 -0.00000   -1.219594
# 2      C[C@H](\C=C(/C)\C=C\C(=O)NO)C(=O)c1ccc(cc1)N(C)C -0.00000   -2.531803
# 3      C[C@H](\C=C(/C)\C=C\C(=O)NO)C(=O)c1ccc(cc1)N(C)C -0.00000   -2.531803
# 4              CC(C=CC(=O)NO)C=C(C)C(=O)c1ccc(cc1)N(C)C -0.00000   -1.088851
# ...                                                 ...      ...         ...
# 8324  CC1(C)CCCCN1C(=O)[C@@H]1CCC(=O)N1c1ccc(-c2noc(... -1.80618   -1.834588
# 8325          FC(F)(F)c1nc(no1)-c1ccc(CNC2CCCCNC2=O)nc1 -1.80618   -1.708438
# 8326         COc1cccc(NCc2ccc(cc2)-c2noc(n2)C(F)(F)F)c1 -1.80618   -1.769439
# 8327  CN1CCN(CC(=O)N(Cc2ccc(cc2)-c2noc(n2)C(F)(F)F)c... -1.80618   -1.700194
# 8328  Cc1noc(n1)[C@H]1CCCCN1c1cc(F)c(cc1F)-c1noc(n1)... -1.80618   -1.901083
#
# [8329 rows x 3 columns]

# %%
import numpy as np
for molecule in set(dupl_data[mol_column]):
  if molecule not in data[mol_column]:
    molecule_table = dupl_data[dupl_data[mol_column] == molecule]
    mol_props = np.array(molecule_table[target_column])
    pred_props = np.array(molecule_table["prediction"])
    prop_differences = np.abs(mol_props - pred_props)
    best_prop = mol_props[np.argmin(prop_differences)]
    dupl_data = dupl_data[dupl_data["Ligand SMILES"] != molecule]
    dupl_data = pd.concat([dupl_data, pd.DataFrame({"Ligand SMILES": [molecule], "pIC50": [best_prop], "prediction": pred_props[0]})], ignore_index=True)
dupl_data
# Out:
#                                           Ligand SMILES     pIC50  prediction
# 0                 ONC(=O)c1ccc2oc(nc2c1)-c1ccc(F)c(F)c1 -1.556303   -1.460416
# 1     COCCS(=O)(=O)N(Cc1ncc(s1)-c1nnc(o1)C(F)F)c1cnc... -1.079181   -2.087882
# 2               FC(F)c1nnc(-c2ccc(Cn3cnc4ccccc43)cc2)o1 -2.587711   -2.529853
# 3                    CNC(=O)c1ccc(Nc2c[nH]c3ccccc23)cc1 -2.301030   -2.564188
# 4                       OC(=O)CCc1nc2ccccc2nc1Sc1ccccc1 -4.778151   -4.817886
# ...                                                 ...       ...         ...
# 6320        FC(F)(F)C(=O)c1ccc([nH]1)C(=O)N1CCc2ccccc12 -2.944483   -2.904366
# 6321                            NS(=O)(=O)c1ccc(SCCO)s1 -3.301030   -3.319073
# 6322  CCC(=O)CCCCC[C@H](NC(=O)[C@H]1CC11CCN(C)CC1)c1... -3.886491   -3.242912
# 6323  ONC(=O)c1ccc(CN(C2CC2)S(=O)(=O)c2c(F)c(Cl)c(F)... -1.176091   -1.176962
# 6324  CS(=O)(=O)NC[C@H](Nc1ncc(cn1)-c1nnc(o1)C(F)F)c... -1.491362   -2.258200
#
# [6325 rows x 3 columns]
